# %%
import pandas as pd

# %%
df_sold = pd.read_csv ('sold_cleaned_11.21.23.csv', low_memory=False)

# %%
df_sold = df_sold[['style', 'street', 'unit', 'city', 'state', 'zip_code',
                   'beds', 'full_baths', 'half_baths', 'sqft', 'year_built',
                   'list_price', 'sold_price', 'latitude', 'longitude', 'metro_area']]

# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np
np.random.seed(42)

 
# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (9, 9)

import seaborn as sns

from IPython.core.pylabtools import figsize

# Scipy helper functions
from scipy.stats import percentileofscore
from scipy import stats

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
df_sold = df_sold.dropna(subset=['sold_price']).reset_index(drop=True)
df_sold = df_sold.dropna(subset=['list_price']).reset_index(drop=True)
df_sold = df_sold.dropna(subset=['zip_code']).reset_index(drop=True)
df_sold = df_sold.dropna(subset=['sqft']).reset_index(drop=True)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame called prices_df
# Select relevant columns for the features and target
features = df_sold[["zip_code", "sqft", "list_price"]]
target = df_sold["sold_price"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create and train the Bayesian Ridge Regression model
bayesian_ridge = BayesianRidge()
bayesian_ridge.fit(X_train, y_train)

# Make predictions on the test set
y_pred = bayesian_ridge.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Optionally, you can visualize the results
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Sold Price')
plt.ylabel('Predicted Sold Price')
plt.title('Actual vs Predicted Sold Price')
plt.show()
# Out:
# Mean Squared Error: 11535813244.350822

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, explained_variance_score, mean_squared_log_error
import numpy as np

# Assuming you already have y_test and y_pred from your Bayesian Ridge Regression model

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Deviation (MAD)
mad = median_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Calculate Root Mean Squared Logarithmic Error (RMSLE)
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))

# Calculate Explained Variance Score (EVS)
evs = explained_variance_score(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# Print or use the values as needed
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Deviation (MAD): {mad}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}')
print(f'Root Mean Squared Logarithmic Error (RMSLE): {rmsle}')
print(f'Explained Variance Score (EVS): {evs}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error (MSE): 11535813244.350822
# Root Mean Squared Error (RMSE): 107404.90326028333
# Mean Absolute Error (MAE): 35073.15226907663
# Mean Absolute Deviation (MAD): 20775.601734039956
# Mean Absolute Percentage Error (MAPE): 0.06020185719401034
# Root Mean Squared Logarithmic Error (RMSLE): 0.089160876623415
# Explained Variance Score (EVS): 0.9807192690649617
# R^2 Score: 0.9807123040326078

# %%
new_data_point = {"zip_code": 90805, "sqft": 5809, "list_price": 839000}

new_data_single = pd.DataFrame([new_data_point])

new_data_single_features = new_data_single[["zip_code", "sqft", "list_price"]]

# Use the trained model to predict the sold price for the single data point
predicted_sold_price_single = bayesian_ridge.predict(new_data_single_features)

# Display or use the predicted sold price as needed
print(predicted_sold_price_single)
# Out:
# [878073.37462148]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame called prices_df
# Select relevant columns for the features and target
features = df_sold[["zip_code", "sqft", "list_price"]]
target = df_sold["sold_price"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create and train the KNN model
knn_model = KNeighborsRegressor(n_neighbors=12)  # You can adjust the number of neighbors (k)
knn_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_model.predict(X_test)

# Optionally, you can visualize the results
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Sold Price')
plt.ylabel('Predicted Sold Price')
plt.title('Actual vs Predicted Sold Price (KNN Regression)')
plt.show()

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Deviation (MAD)
mad = median_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Calculate Root Mean Squared Logarithmic Error (RMSLE)
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))

# Calculate Explained Variance Score (EVS)
evs = explained_variance_score(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# Print or use the values as needed
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Deviation (MAD): {mad}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}')
print(f'Root Mean Squared Logarithmic Error (RMSLE): {rmsle}')
print(f'Explained Variance Score (EVS): {evs}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error (MSE): 34006279451.405598
# Root Mean Squared Error (RMSE): 184407.91591308004
# Mean Absolute Error (MAE): 30265.265632269195
# Mean Absolute Deviation (MAD): 12025.0
# Mean Absolute Percentage Error (MAPE): 0.03992776791605549
# Root Mean Squared Logarithmic Error (RMSLE): 0.07014625699851271
# Explained Variance Score (EVS): 0.9431468845423285
# R^2 Score: 0.9431420425116461

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame called prices_df
# Select relevant columns for the features and target
features = df_sold[["zip_code", "sqft", "list_price"]]
target = df_sold["sold_price"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)  # Output layer with a single neuron for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled).flatten()

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Optionally, you can visualize the training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\ycqiu\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\ycqiu\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\ycqiu\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\ycqiu\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Deviation (MAD)
mad = median_absolute_error(y_test, y_pred)

# Calculate Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Calculate Root Mean Squared Logarithmic Error (RMSLE)
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))

# Calculate Explained Variance Score (EVS)
evs = explained_variance_score(y_test, y_pred)

r2 = r2_score(y_test, y_pred)

# Print or use the values as needed
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Deviation (MAD): {mad}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}')
print(f'Root Mean Squared Logarithmic Error (RMSLE): {rmsle}')
print(f'Explained Variance Score (EVS): {evs}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error (MSE): 11513338604.745293
# Root Mean Squared Error (RMSE): 107300.22648972039
# Mean Absolute Error (MAE): 35506.3995558981
# Mean Absolute Deviation (MAD): 21391.3125
# Mean Absolute Percentage Error (MAPE): 0.06233025974035148
# Root Mean Squared Logarithmic Error (RMSLE): 0.09129849320229
# Explained Variance Score (EVS): 0.9807680734114014
# R^2 Score: 0.9807498812719845

# %%
df_forSale = pd.read_excel('for_sale_cleaned_up_11.21.23_updated.xlsx')

# %%
new_data_features = df_forSale[["zip_code", "sqft", "list_price"]]

# Standardize the features using the same scaler used during training
new_data_features_scaled = scaler.transform(new_data_features)

# Use the trained model to predict sold prices for the new data
predicted_sold_prices = model.predict(new_data_features_scaled).flatten()

# Add a new column 'predicted_price' to df_forSale
df_forSale['predicted_price'] = predicted_sold_prices
# Out:
# 856/856 [==============================] - 1s 845us/step

# %%
df_forSale.to_csv('for_sale_predict.csv', index=False)
